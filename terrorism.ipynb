# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
terrorism_df=pd.read_csv('/content/globalterrorismdb_0718dist.csv',encoding='latin=1')

# %%
terrorism_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
terrorism_df.shape
# Out:
# (2909, 135)

# %%
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2909 entries, 0 to 2908
# Columns: 135 entries, eventid to related
# dtypes: float64(62), int64(22), object(51)
# memory usage: 3.0+ MB

# %%
terrorism_df.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  2.909000e+03  2909.000000  2909.000000  2909.000000  2909.000000
# mean   1.972186e+11  1972.122723     6.138536    15.382606     0.032314
# std    1.584058e+08     1.585828     3.421309     9.095383     0.176862
# min    1.970000e+11  1970.000000     0.000000     0.000000     0.000000
# 25%    1.971022e+11  1971.000000     3.000000     7.000000     0.000000
# 50%    1.972083e+11  1972.000000     6.000000    16.000000     0.000000
# 75%    1.974011e+11  1974.000000     9.000000    23.000000     0.000000
# max    1.975033e+11  1975.000000    12.000000    31.000000     1.000000
#
#            country       region     latitude    longitude  specificity  ...  \
# count  2909.000000  2909.000000  2861.000000  2861.000000  2909.000000  ...
# mean    294.377106     5.131317    35.713904   -35.403239     1.088003  ...
# std     208.206269     3.510636    24.617529    53.617887     0.563527  ...
# ...

# %%
terrorism_df.isna().sum()
# Out:
# eventid          0
# iyear            0
# imonth           0
# iday             0
# approxdate    2893
#               ...
# INT_LOG          1
# INT_IDEO         1
# INT_MISC         1
# INT_ANY          1
# related       2649
# Length: 135, dtype: int64

# %%
terrorism_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
terrorism_df=terrorism_df[["iyear","imonth","iday","country_txt","region_txt","provstate","city","latitude","longitude","location","summary","attacktype1","targtype1_txt","gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
terrorism_df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#    attacktype1                targtype1_txt  \
# 0            1  Private Citizens & Property
# ...

# %%
terrorism_df.shape
# Out:
# (2909, 19)

# %%
terrorism_df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country","region_txt":"Region","provstate":"Province/State","city":"City","nkill":"killed","nwound":"wounded"},inplace=True)

# %%
terrorism_df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   latitude   longitude location summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#    attacktype1                targtype1_txt  \
# 0            1  Private Citizens & Property
# ...

# %%
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2909 entries, 0 to 2908
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            2909 non-null   int64
#  1   Month           2909 non-null   int64
#  2   Day             2909 non-null   int64
#  3   Country         2909 non-null   object
#  4   Region          2909 non-null   object
#  5   Province/State  2899 non-null   object
#  6   City            2909 non-null   object
#  7   latitude        2861 non-null   float64
#  8   longitude       2861 non-null   float64
#  9   location        461 non-null    object
#  10  summary         721 non-null    object
#  11  attacktype1     2909 non-null   int64
#  12  targtype1_txt   2909 non-null   object
#  13  gname           2909 non-null   object
#  14  motive          460 non-null    object
#  15  weaptype1_txt   2909 non-null   object
#  16  killed          2604 non-null   float64
# ...

# %%
terrorism_df.shape
# Out:
# (2909, 19)

# %%
terrorism_df.isnull().sum()
# Out:
# Year                 0
# Month                0
# Day                  0
# Country              0
# Region               0
# Province/State      10
# City                 0
# latitude            48
# longitude           48
# location          2448
# summary           2188
# attacktype1          0
# targtype1_txt        0
# gname                0
# motive            2449
# weaptype1_txt        0
# killed             305
# wounded           1062
# addnotes          2392
# dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=terrorism_df,x='Year')
plt.title('count of terrorist activities each year')
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(data=terrorism_df,x='Year',y='killed')
plt.show()

# %%
terrorism_df.Year
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 2904    1975
# 2905    1975
# 2906    1975
# 2907    1975
# 2908    1975
# Name: Year, Length: 2909, dtype: int64

# %%
import missingno as msgo
msgo.matrix(terrorism_df)
# Out:
# <Axes: >
